# %% [markdown]
# # Zillow Zestimate Overview

# %%
import pandas as pd
import gc

from bokeh.charts import Histogram, Bar, BoxPlot, Scatter, show
from bokeh.io import output_notebook
from bokeh.layouts import gridplot

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d046ba9-9784-4184-8aab-3be755bb54ef">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Train dataset (short)

# %% [markdown]
# Short means that only 3 columns are present (parcelid, logerror, tansactiondate)

# %%
train_2016_short = pd.read_csv("../data/train_2016.csv", parse_dates=["transactiondate"])
print(train_2016_short.shape)
print("from:", train_2016_short["transactiondate"].min())
print("to:  ", train_2016_short["transactiondate"].max())
train_2016_short.head()
# Out:
# (90811, 3)
# from: 2016-01-01 00:00:00
# to:   2016-12-30 00:00:00
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# ### <font color="blue">logerror</font>

# %%
h = Histogram(train_2016_short["logerror"], title="logerror distribution", tools=["xwheel_zoom"], width=900, height=350)

train_2016_short["label"] = "0"
p = BoxPlot(train_2016_short, label="label", values='logerror', title="logerror dispersion", 
            tools=["ypan", "ywheel_zoom", "save"], width=700, height=350)

show(gridplot([[h], [p]]))

del train_2016_short["label"]
del h
del p
gc.collect()

# %%
train_2016_logerror_0 = train_2016_short[train_2016_short["logerror"] == 0]
logerror_percent_0 = str(round(100 * len(train_2016_logerror_0)/ float(len(train_2016_short)), 4))
print(logerror_percent_0 + "% of ZERO error")

# %% [markdown]
# ### <font color="blue">transactiondate</font>

# %%
months = train_2016_short["transactiondate"].astype(str).str.slice(0,7)

time_freqs = pd.DataFrame(months.value_counts())

p = Bar(time_freqs, values='transactiondate', title="monthly transactiondate distribution", legend=False,
        width=800, height=350)
show(p)

del months
del time_freqs
del p
gc.collect()

# %% [markdown]
# ### <font color="blue">parcelid</font>

# %% [markdown]
# duplicated parcelids

# %%
is_duplicated = train_2016_short["parcelid"].duplicated()
duplicated_ids = train_2016_short[is_duplicated]["parcelid"]
duplicateds = train_2016_short[train_2016_short["parcelid"].isin(duplicated_ids)].sort_values(["parcelid"])

duplicateds.head(10)

h = Histogram(duplicateds["logerror"], title="logerror distribution for resold properties", tools=["xwheel_zoom"], width=900, height=350)
show(h)

del h
gc.collect()

# %% [markdown]
# Bought and sold again

# %% [markdown]
# ## Properties dataset

# %% [markdown]
# Train data

# %%
prop_2016 = pd.read_csv("../data/properties_2016.csv", low_memory=False)
print(prop_2016.shape)
#print(prop_2016.columns)
prop_2016.head()
# Out:
# (2985217, 58)
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                NaN         NaN         ...                       NaN
# 1                NaN         NaN         ...                       NaN
# 2                NaN         NaN         ...                       NaN
# 3                NaN         NaN         ...                       1.0
# 4                NaN         NaN         ...                       NaN
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0            NaN                         NaN                9.0
# 1            NaN                         NaN            27516.0
# 2            NaN                    650756.0          1413387.0
# 3            NaN                    571346.0          1156834.0
# 4            NaN                    193796.0           433491.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0          2015.0                    9.0        NaN                 NaN
# 1          2015.0                27516.0        NaN                 NaN
# 2          2015.0               762631.0   20800.37                 NaN
# 3          2015.0               585488.0   14557.57                 NaN
# 4          2015.0               239695.0    5725.17                 NaN
#
#    taxdelinquencyyear  censustractandblock
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 58 columns]

# %%
print(len(prop_2016["parcelid"].drop_duplicates()))
print(len(train_2016_short["parcelid"].drop_duplicates()))
# Out:
# 2985217
# 90682

# %% [markdown]
# Completing train dataset with attributes from properties

# %%
train_complete_2016 = train_2016_short.merge(prop_2016, on="parcelid", how="left")
train_complete_2016.shape
# Out:
# (90811, 60)

# %% [markdown]
# Inserting information about the signal of the logerror

# %%
train_complete_2016["error_direction"] = 0

positive_index = train_complete_2016[train_complete_2016["logerror"] > 0].index
train_complete_2016.loc[positive_index, "error_direction"] = 1

positive_index = train_complete_2016[train_complete_2016["logerror"] < 0].index
train_complete_2016.loc[positive_index, "error_direction"] = -1

# %% [markdown]
# Plotting the location of the properties, the color represents the signal of the logerror.<br>
# It seems difficult to have an insight even if zooming in.<br>

# %%
p = Scatter(train_complete_2016, x='longitude', y='latitude', color="error_direction",
            title="Geographic scatter plot",
            xlabel="longitude", ylabel="latitude",
            width=900, height=600)

show(p)

train_complete_2016["error_direction"].value_counts()

#del p
#gc.collect()

# %%
train_complete_2016["latitude"].isnull().sum(), train_complete_2016["longitude"].isnull().sum()

# %% [markdown]
# Generating column with the logerror mean for the k neighbors since it was difficult to check it visually with the above plot.

# %%
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

def fit_knn(df, k):
    df = df.dropna(subset=["latitude", "longitude"])
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='ball_tree').fit(df[["latitude", "longitude"]])
    return nbrs
    
def k_neighbors_logerror_mean(df_train, df_test, nbrs):        
    logerror_means = []
    distance_means = []
    df_train = df_train.dropna(subset=["latitude", "longitude"])
    df_test = df_test.dropna(subset=["latitude", "longitude"])
    
    for index, row in df_test.iterrows():
        distances, indexes = nbrs.kneighbors(row[["latitude", "longitude"]])
        distances = list(distances[0])
        indexes = list(indexes[0])
        #sometimes there are more than k neighbors with the same location
        if index in indexes:
            indexes.remove(index)
            distances.remove(0)
        
        neighbors = df_train.iloc[indexes]
        neighbors_logerror_mean = neighbors["logerror"].mean()
        neighbors_distance_mean = float(sum(distances)) / len(distances)
        
        logerror_means.append(neighbors_logerror_mean)
        distance_means.append(neighbors_distance_mean)
        
    df_test["nbrs_logerror_mean"] = logerror_means
    df_test["nbrs_distance_mean"] = distance_means
    
    return df_test

nbrs = fit_knn(train_complete_2016, 2)
train_complete_2016 = k_neighbors_logerror_mean(train_complete_2016, train_complete_2016, nbrs)
gc.collect()
# Out:
# 740

# %% [markdown]
# Checking the **nbrs_logerror_mean** correlation with **logerror**

# %%
print("spearman:", train_complete_2016["logerror"].corr(train_complete_2016["nbrs_logerror_mean"], method="spearman"))
print("pearson :", train_complete_2016["logerror"].corr(train_complete_2016["nbrs_logerror_mean"], method="pearson"))
# Out:
# spearman: 0.643235761132
# pearson : 0.687486975183

# %% [markdown]
# Checking for correlation between absolute values from **nbrs_logerror_mean** and **logerror**

# %%
print("spearman:", abs(train_complete_2016["logerror"]).corr(abs(train_complete_2016["nbrs_logerror_mean"]), method="spearman"))
print("pearson: ", abs(train_complete_2016["logerror"]).corr(abs(train_complete_2016["nbrs_logerror_mean"]), method="pearson"))
# Out:
# spearman: 0.505480964238
# pearson:  0.670493796109

# %% [markdown]
# All numeric columns correlations

# %%
corr_dicts = []
for col in train_complete_2016.columns:
    try:
        corr_dicts.append({"column": col, "corr": train_complete_2016[col].astype('float64').corr(train_complete_2016["logerror"])})
    except (TypeError, ValueError):
        pass
corr_df = pd.DataFrame(corr_dicts).sort_values(by="corr", ascending=False) 
corr_df
# Out:
#                           column      corr
# 1                       logerror  1.000000
# 57            nbrs_logerror_mean  0.687487
# 56               error_direction  0.421615
# 4                   basementsqft  0.253395
# 45            yardbuildingsqft26  0.086179
# 13          finishedsquarefeet12  0.041922
# 12  calculatedfinishedsquarefeet  0.038784
# 17           finishedsquarefeet6  0.036847
# 14          finishedsquarefeet13  0.034715
# 41           threequarterbathnbr  0.034069
# 19                  fireplacecnt  0.033235
# 9              calculatedbathnbr  0.029448
# 20                   fullbathcnt  0.028845
# 5                    bathroomcnt  0.027889
# 21                  garagecarcnt  0.026531
# 11      finishedfloor1squarefeet  0.026242
# 6                     bedroomcnt  0.025467
# 22               garagetotalsqft  0.023888
# 16          finishedsquarefeet50  0.023619
# 49    structuretaxvaluedollarcnt  0.022085
# 58            nbrs_distance_mean  0.021365
# 15          finishedsquarefeet15  0.019327
# 46                     yearbuilt  0.017312
# 47               numberofstories  0.013075
# 55           censustractandblock  0.008892
# 34        rawcensustractandblock  0.008376
# 18                          fips  0.008363
# 50             taxvaluedollarcnt  0.006508
# 39                       roomcnt  0.005760
# 2          airconditioningtypeid  0.005179
# 25                      latitude  0.004915
# 0                       parcelid  0.004837
# 27             lotsizesquarefeet  0.004835
# 33         propertylandusetypeid  0.001003
# 36                regionidcounty  0.000341
# 29                   poolsizesum -0.000454
# 35                  regionidcity -0.002121
# 52         landtaxvaluedollarcnt -0.003051
# 26                     longitude -0.003432
# 43                       unitcnt -0.003983
# 3       architecturalstyletypeid -0.004276
# 37          regionidneighborhood -0.004638
# 38                   regionidzip -0.006507
# 53                     taxamount -0.006671
# 8          buildingqualitytypeid -0.009573
# 54            taxdelinquencyyear -0.012996
# 42        typeconstructiontypeid -0.022419
# 44            yardbuildingsqft17 -0.023692
# 24         heatingorsystemtypeid -0.025018
# 7            buildingclasstypeid       NaN
# 10                    decktypeid       NaN
# 23                hashottuborspa       NaN
# 28                       poolcnt       NaN
# 30                  pooltypeid10       NaN
# 31                   pooltypeid2       NaN
# 32                   pooltypeid7       NaN
# 40                   storytypeid       NaN
# 48                 fireplaceflag       NaN
# 51                assessmentyear       NaN

# %%
p = Scatter(train_complete_2016, x='logerror', y='nbrs_logerror_mean',
            title="logerror by nbrs_logerror_mean scatter plot",
            xlabel="logerror", ylabel="nbrs_logerror_mean",
            width=900, height=600)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c3e4bbcb-0ec9-423a-943d-711a8118126e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c3e4bbcb-0ec9-423a-943d-711a8118126e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c3e4bbcb-0ec9-423a-943d-711a8118126e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c3e4bbcb-0ec9-423a-943d-711a8118126e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2a7da63a-7068-41cd-a37a-34e36c72e7cf":{"roots":{"references":[{"attributes":{"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"}},"id":"3b0491a2-5350-4c7b-852e-bbd2c54a22ea","type":"ResetTool"},{"attributes":{},"id":"8130f428-0e41-4034-8249-9aee2f9e9d20","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"}},"id":"d1c57518-77c2-44e2-a3ea-c3a3933d8991","type":"PanTool"},{"attributes":{"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"}},"id":"bc5cb34f-29c2-41a2-a127-5e48b93448ff","type":"HelpTool"},{"attributes":{"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"}},"id":"bec9faad-a6dd-4543-abb8-f7157fe0e343","type":"SaveTool"},{"attributes":{"data_source":{"id":"a9a20c44-6cfe-4f4a-9b10-ca3c7f8fe98a","type":"ColumnDataSource"},"glyph":{"id":"0295de2d-f42d-4915-921d-f57b44e0f840","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"c0bf6684-fc7a-4cd3-89c5-3d6db96a3fc6","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"44527286-4973-4b48-84bb-95329aba7a11","type":"BoxAnnotation"},"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"}},"id":"0d2b9f67-32ac-4d09-9eb9-397118b4485a","type":"BoxZoomTool"},{"attributes":{},"id":"cc393446-6a87-4c4e-ba39-1b4c96170c02","type":"ToolEvents"},{"attributes":{"plot":null,"text":"logerror by nbrs_logerror_mean scatter plot"},"id":"c12a8e8a-df2a-46ae-a841-9cbb8dc156d1","type":"Title"},{"attributes":{},"id":"014c057d-2719-4164-998a-59c7ecd5ab28","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d1c57518-77c2-44e2-a3ea-c3a3933d8991","type":"PanTool"},{"id":"330fac2a-7e7b-4523-a8cf-177fe8848bfe","type":"WheelZoomTool"},{"id":"0d2b9f67-32ac-4d09-9eb9-397118b4485a","type":"BoxZoomTool"},{"id":"bec9faad-a6dd-4543-abb8-f7157fe0e343","type":"SaveTool"},{"id":"3b0491a2-5350-4c7b-852e-bbd2c54a22ea","type":"ResetTool"},{"id":"bc5cb34f-29c2-41a2-a127-5e48b93448ff","type":"HelpTool"}]},"id":"81eef528-0782-4891-84d5-c1e34b60e1e2","type":"Toolbar"},{"attributes":{"below":[{"id":"c76e9b50-75dd-47f0-870f-386aac20c89e","type":"LinearAxis"}],"css_classes":null,"height":600,"left":[{"id":"756e5755-4584-44b5-881a-c966acad8559","type":"LinearAxis"}],"renderers":[{"id":"44527286-4973-4b48-84bb-95329aba7a11","type":"BoxAnnotation"},{"id":"c0bf6684-fc7a-4cd3-89c5-3d6db96a3fc6","type":"GlyphRenderer"},{"id":"425de39e-f41c-4054-978d-4d60b95b640c","type":"Legend"},{"id":"c76e9b50-75dd-47f0-870f-386aac20c89e","type":"LinearAxis"},{"id":"756e5755-4584-44b5-881a-c966acad8559","type":"LinearAxis"},{"id":"e4f70c60-f740-4296-9b91-12bf4e9535dc","type":"Grid"},{"id":"6a27998f-b440-4fd2-a75c-eef1e951e6d3","type":"Grid"}],"title":{"id":"c12a8e8a-df2a-46ae-a841-9cbb8dc156d1","type":"Title"},"tool_events":{"id":"cc393446-6a87-4c4e-ba39-1b4c96170c02","type":"ToolEvents"},"toolbar":{"id":"81eef528-0782-4891-84d5-c1e34b60e1e2","type":"Toolbar"},"width":900,"x_mapper_type":"auto","x_range":{"id":"6a324b30-cbf6-4ad1-8488-478548a1b90b","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"ea8807fb-e4ee-4990-b923-d416b0aa24a1","type":"Range1d"}},"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"0c42bab8-8d12-4098-9ab4-99c60c38ca60","type":"BasicTicker"},{"attributes":{"plot":{"id":"cc457c13-e9a4-42d9-9cb9-e8ced8643e2f","subtype":"Chart","type":"Plot"},"ticker":{"id":"0c42bab8-8d12-4098-9ab4-99c60c38ca60","type":"BasicTicker"}},"id":"e4f70c60-f740-4296-9b91-12bf4e9535dc","type":"Grid"},{"attributes":{"callback":null,"end":5.1625250000000005,"start":-2.9977750000000003},"id":"ea8807fb-e4ee-4990-b923-d416b0aa24a1","type":"Range1d"},{"attributes":{"axis_label":"nbrs_logerror_mean","formatter":{"id":"0779a98d-c394-4a92-aaee-e8b3c8ff1004","type":"BasicTickFormatter"},"plot":{"id":"cc457 ...

# %%
higests_corr_columns = corr_df[corr_df["corr"] > 0.15].column.tolist()
higests_corr_columns.remove("error_direction")
higests_corr_columns = ["parcelid"] + higests_corr_columns

train = train_complete_2016[higests_corr_columns]
train.to_csv("/home/tales/dev/projects/zillow-zestimate/train-1.csv", index=False)

# %%
#higests_corr_columns.remove("logerror")
test = k_neighbors_logerror_mean(train_complete_2016, prop_2016, nbrs)[higests_corr_columns]
test.to_csv("/home/tales/dev/projects/zillow-zestimate/test-1.csv", index=False)
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-1-9ff3ad03010e> in <module>()
#       1 #higests_corr_columns.remove("logerror")
# ----> 2 test = k_neighbors_logerror_mean(train_complete_2016, prop_2016, nbrs)[higests_corr_columns]
#       3 test.to_csv("/home/tales/dev/projects/zillow-zestimate/test-1.csv", index=False)
#
# NameError: name 'k_neighbors_logerror_mean' is not defined

# %%
test.merge(train, on="parcelid", how="inner")
gc.collect()
# Out:
# 4133

# %%
prop_2016_no_na = prop_2016[["latitude", "longitude"]].dropna()
prop_2016_no_na.head()
len(prop_2016_no_na), len(prop_2016), prop_2016_no_na.index.max(), prop_2016.index.max()

# %%
prop_2016_no_na[["latitude", "longitude"]].tail()
