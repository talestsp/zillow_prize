# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import gc
import warnings

from bokeh.charts import Histogram, Bar, BoxPlot, Scatter, show
from bokeh.plotting import figure
from bokeh.io import output_notebook
from bokeh.layouts import gridplot

output_notebook()
pd.set_option('display.float_format', lambda x: '%.3f' % x)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="60880355-fbde-470a-a156-f7afa7cb88d7">Loading BokehJS ...</span>
#     </div>

# %%
train_2016_short = pd.read_csv("../data/train_2016.csv", parse_dates=["transactiondate"])
prop_2016 = pd.read_csv("../data/properties_2016.csv", low_memory=False)

# %%
train = train_2016_short.merge(prop_2016, on="parcelid", how="left")
train = train.set_index(train["parcelid"])
train = train[["latitude", "longitude", "logerror"]]
train.head()
# Out:
#             latitude    longitude  logerror
# parcelid
# 11016594  34280990.0 -118488536.0    0.0276
# 14366692  33668120.0 -117677556.0   -0.1684
# 12098116  34136312.0 -118175032.0   -0.0040
# 12643413  33755800.0 -118309000.0    0.0218
# 14432541  33485643.0 -117700234.0   -0.0050

# %%
def fit_knn(df, cols, k):
    df = df.dropna(subset=cols)
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='brute').fit(df[cols])
    return nbrs

def k_neighbors_logerror_mean(df_train, df_test, cols, new_column, nbrs):
    logerror_means = []

    df_train = df_train.dropna(subset=cols).copy()
    df_test = df_test.dropna(subset=cols).copy()

    for index, row in df_test.iterrows():
        kn_distances, kn_indexes = nbrs.kneighbors(row[cols])
        kn_indexes = list(kn_indexes[0])

        neighbors = df_train.iloc[kn_indexes]
        neighbors = neighbors[neighbors.index != index]

        neighbors_logerror_mean = neighbors["logerror"].mean()

        logerror_means.append(neighbors_logerror_mean)
        
    df_test[new_column] = logerror_means
        
    return df_test[[new_column]]

# %%
cols = ["latitude", "longitude"]
nbrs = fit_knn(train, cols, 2)

nearest_logerror = k_neighbors_logerror_mean(train, train, cols, "nearest_logerror", nbrs)

use_train = train.join(nearest_logerror, how="inner")

# %% [markdown]
# ### Correlations between <font color='blue'>logerror</font>  and <font color='blue'>logerror of the nearest neighbor</font>

# %% [markdown]
# abs means that it was considered the absolute values of both columns logerror and nearest_logerror

# %%
print("pearson     :", use_train["logerror"].corr(use_train["nearest_logerror"], method="pearson"))
print("spearman    :", use_train["logerror"].corr(use_train["nearest_logerror"], method="spearman"))
print("abs pearson :", abs(use_train["logerror"]).corr(abs(use_train["nearest_logerror"]), method="pearson"))
print("abs spearman:", abs(use_train["logerror"]).corr(abs(use_train["nearest_logerror"]), method="spearman"))
use_train.head()
# Out:
# pearson     : 0.0483033176882
# spearman    : 0.0678755405492
# abs pearson : 0.0717932717364
# abs spearman: 0.105052610434
#              latitude      longitude  logerror  error  nearest_logerror
# parcelid
# 10711738 34220381.000 -118620802.000     0.028  1.000            -0.026
# 10711755 34222040.000 -118622240.000    -0.018 -1.000             0.028
# 10711805 34220427.000 -118618549.000    -0.101 -1.000            -0.012
# 10711816 34222390.000 -118618631.000    -0.012 -1.000            -0.048
# 10711858 34222544.000 -118617961.000    -0.048 -1.000            -0.012

# %% [markdown]
# ### Scatter plot of <font color='blue'>x = logerror</font> and <font color='blue'>y = nearest_logerror</font>

# %% [markdown]
# In blue with signal, in green without (abs)

# %%
p = figure(plot_width=450, plot_height=450, title="")
p.circle(use_train['logerror'], use_train['nearest_logerror'], size=3, alpha=0.2)

p_abs = figure(plot_width=450, plot_height=450, title="")
p_abs.circle(abs(use_train['logerror']), abs(use_train['nearest_logerror']), color="green", size=3, alpha=0.2)

show(gridplot([[p, p_abs]]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d35806fa-884f-48d1-b0ea-515f20cc32df"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d35806fa-884f-48d1-b0ea-515f20cc32df");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d35806fa-884f-48d1-b0ea-515f20cc32df");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd35806fa-884f-48d1-b0ea-515f20cc32df' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dbce2e79-2a6a-48ed-a73a-499b26c02586":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d3f5a7cf-176d-4dd9-9a8c-ad9e8e1a9399","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"d3f5a7cf-176d-4dd9-9a8c-ad9e8e1a9399","type":"BoxAnnotation"},"plot":{"id":"3d4ffe44-4065-468b-9150-70d85422f2d1","subtype":"Figure","type":"Plot"}},"id":"b8a40f14-96ee-46ab-b2ec-e748a74fc1bc","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"12252978-b37e-4d4c-9b2e-2284535a530d","type":"PanTool"},{"id":"f6653898-5610-43d3-b868-8f381e6bd52f","type":"WheelZoomTool"},{"id":"43d929b9-3352-4640-8e7d-7d57fc992667","type":"BoxZoomTool"},{"id":"5aac99a2-bedf-40c0-af47-c8c99ba8afd6","type":"SaveTool"},{"id":"17c9e385-21d8-4d83-b7ac-4936775d850a","type":"ResetTool"},{"id":"96043ec8-b315-4b32-86e2-1b78549a6c47","type":"HelpTool"}]},"id":"dd99b8b5-bdb6-4cfc-a307-f469d9ada735","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"17f88c05-ce7a-48d6-8817-f0018e157644","type":"Title"},{"attributes":{"plot":{"id":"2add9951-508a-4d4d-b04b-9a61d61cfbe0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b76ada03-6bbb-41f6-8ff7-b5006efb986d","type":"BasicTicker"}},"id":"032acd28-6910-4c71-8ef6-00b74fa8ec28","type":"Grid"},{"attributes":{"formatter":{"id":"73ba94c5-8ee1-4f2f-8a21-beac66983354","type":"BasicTickFormatter"},"plot":{"id":"3d4ffe44-4065-468b-9150-70d85422f2d1","subtype":"Figure","type":"Plot"},"ticker":{"id":"e006d6d4-9c55-47f6-b0b8-01d0898c28f8","type":"BasicTicker"}},"id":"197568bd-27be-43b9-9aed-94406de83f93","type":"LinearAxis"},{"attributes":{},"id":"e006d6d4-9c55-47f6-b0b8-01d0898c28f8","type":"BasicTicker"},{"attributes":{},"id":"73ba94c5-8ee1-4f2f-8a21-beac66983354","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3d4ffe44-4065-468b-9150-70d85422f2d1","subtype":"Figure","type":"Plot"}},"id":"149f8043-1d16-45e5-af04-3abf8ef2055f","type":"PanTool"},{"attributes":{"children":[{"id":"72f60430-d54d-4423-a687-2f7f763d41e4","type":"Row"}]},"id":"3e8860fd-6cee-4955-80e5-a98b26a9f0f1","type":"Column"},{"attributes":{"callback":null},"id":"697537cb-7c83-45d6-8b35-1ab7ef48da4c","type":"DataRange1d"},{"attributes":{"plot":{"id":"2add9951-508a-4d4d-b04b-9a61d61cfbe0","subtype":"Figure","type":"Plot"}},"id":"5aac99a2-bedf-40c0-af47-c8c99ba8afd6","type":"SaveTool"},{"attributes":{"data_source":{"id":"afceec84-4d0f-4c9a-81d3-751f14f1beb2","type":"ColumnDataSource"},"glyph":{"id":"0fce6f96-04a8-4109-b588-a7c2a5ed7683","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a42a71eb-001d-413b-89d7-9085b07186c8","type":"Circle"},"selection_glyph":null},"id":"d0255ca6-8688-42bc-9eca-2cf582bf1b13","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"beabfce8-2fe4-45e8-a751-5c6ff350a04b","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a42a71eb-001d-413b-89d7-9085b07186c8","type":"Circle"},{"attributes":{"plot":{"id":"3d4ffe44-4065-468b-9150-70d85422f2d1","subtype":"Figure","type":"Plot"}},"id":"50cf86a0-7506-4f83-973d-6c270ba5621a","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[90527]},"y":{"__ndarray__":"...","dtype":"float64","shape":[90527]}}},"id":"afceec84-4d0f-4c9a-81d3-751f14f1beb2","type":"ColumnDataSource"},{"attributes":{},"id":"234599fd-fb53-4946-a5a3-43ff82f5747b","type":"BasicTicker"},{"attributes":{"overlay":{"id":"9768a1f7-a801-414e-b863-2d0a5 ...

# %%
def k_neighbors_ll(df_train, df_test, cols, new_column, nbrs):
    neighbors_lat = []
    neighbors_lon = []
    df_train = df_train.dropna(subset=cols).copy()
    df_test = df_test.dropna(subset=cols).copy()

    for index, row in df_test.iterrows():

        kn_distances, kn_indexes = nbrs.kneighbors(row[cols])
        kn_indexes = list(kn_indexes[0])

        neighbors = df_train.iloc[kn_indexes]
        neighbors = neighbors[neighbors.index != index]
    
        neighbor_lat = neighbors["latitude"].item()
        neighbor_lon = neighbors["longitude"].item()
        
        neighbors_lat.append(neighbor_lat)
        neighbors_lon.append(neighbor_lon)
        
    df_test["n_lat"] = neighbors_lat
    df_test["n_lon"] = neighbors_lon
        
    return df_test[["n_lat", "n_lon"]]

# %%
cols = ["latitude", "longitude"]
nbrs = fit_knn(train.head(50), cols, 2)

nearest_logerror = k_neighbors_ll(train.head(50), train.head(50), cols, "nearest_logerror", nbrs)

train_ll = train.join(nearest_logerror, how="inner")

# %% [markdown]
# ### We can check that the algorithm is working good by checking a line between a point and its closest neighbor

# %%
p = figure(plot_width=450, plot_height=350, title="Closest Neighbors")

for index, row in train_ll.head(50).iterrows():  
    p.circle(row['longitude'], row['latitude'], size=5, alpha=1)
    line = pd.DataFrame({"x": [row['longitude'], row["n_lon"]], "y": [row['latitude'], row["n_lat"]] })
    p.line(line["x"], line["y"], line_width=1, color="magenta")
    
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="72f453cb-ca4b-42a0-97db-98d174b4c52b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("72f453cb-ca4b-42a0-97db-98d174b4c52b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("72f453cb-ca4b-42a0-97db-98d174b4c52b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '72f453cb-ca4b-42a0-97db-98d174b4c52b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"297de5d1-daed-4491-813e-9cf90e492ac4":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-117678000.0},"y":{"value":33549600.0}},"id":"4f359337-e554-4157-9219-829ce5fbaa3e","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0997d8b-858b-483b-ba73-4216c5eb629f","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc138847-9456-42bf-b0fb-7f7bd263fa38","type":"Line"},{"attributes":{"callback":null,"data":{}},"id":"4f5c033b-38d6-4614-bc8a-a16db82192b8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-117819432.0},"y":{"value":33993442.0}},"id":"7efc009c-d114-498d-85e6-d9f396f57a86","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-118141000.0},"y":{"value":33780400.0}},"id":"c0f0ad12-ca3e-4041-8775-6c2ec1842de1","type":"Circle"},{"attributes":{"data_source":{"id":"80c99042-0087-4348-998d-342e8ca9fb4b","type":"ColumnDataSource"},"glyph":{"id":"bf835665-07e4-46eb-8f8b-ce9e3840aff1","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"37112e81-1fac-4191-a9c8-7b01aa275c9d","type":"Circle"},"selection_glyph":null},"id":"11ec82ab-8ea7-40c9-9ea2-dd03e9506187","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAALAMUnMEAAABgURicwQ==","dtype":"float64","shape":[2]},"y":{"__ndarray__":"AAAAeHEcgEEAAABIcxiAQQ==","dtype":"float64","shape":[2]}}},"id":"7c28f186-7052-406d-9bca-56f6341c317d","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"33660b57-8154-4c6d-8828-7912e76b27af","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAA0HcOnMEAAAD06A6cwQ==","dtype":"float64","shape":[2]},"y":{"__ndarray__":"AAAAwOANgEEAAABwNASAQQ==","dtype":"float64","shape":[2]}}},"id":"447cc83c-0152-4724-8702-cff17fe03324","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-117700234.0},"y":{"value":33485643.0}},"id":"6990bf2f-81bf-482c-b83c-ec2b04a59dec","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAIAI1nMEAAABAuzqcwQ==","dtype":"float64","shape":[2]},"y":{"__ndarray__":"AAAAwJQYgEEAAABIiCaAQQ==","dtype":"float64","shape":[2]}}},"id":"3e2d1115-dab8-4f5a-abbe-b95628e49655","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-118309000.0},"y":{"value":33755800.0}},"id":"7b767d83-6221-4c98-ac4f-5e9612a0a172","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-118407194.0},"y":{"value":34280213.0}},"id":"152063c3-d1f8-4c69-bef7-b6704f02f221","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"value":-118522000.0},"y":{"value":34167800.0}},"id":"0a96f97b-32fc-425b-a862-27fc335f1175","type":"Circle"},{"attributes":{"data_source":{"id":"abb0989f-0c52-4b20-9070-e2795e4f922e","type":"ColumnDataSource"},"glyph":{"id":"dd34cc18-da45-4bf0-9de ...

# %% [markdown]
# ### Checking the logerror signal of the neighbors

# %%
train["error_signal"] = train["logerror"] / abs(train["logerror"])
train["error_signal"] = train["error_signal"].fillna(value=0)

cols = ["longitude", "longitude"]

k_geo = []
for k in list(range(2,10)) + list(range(11,50,4)) + list(range(51,500,20)):
    print("k:", k)
    
    nbrs = fit_knn(train, cols, k)

    err_signal = k_neighbors_logerror_mean(train, train, cols, "n_error_signal", nbrs)
    train_signal = train.join(err_signal, how="inner")
    train_signal["n_error_signal"] = train_signal["n_error_signal"] / abs(train_signal["n_error_signal"])
    train_signal["error_signal"] = train_signal["error_signal"].fillna(value=0)
    
    freq_correct_signal = (train_signal["error_signal"] == train_signal["n_error_signal"]).value_counts()
    ac = freq_correct_signal[True] / len(train_signal)

    k_geo.append({"k": k, "accuracy": ac})
    print(ac)
    print()
    
k_geo_df = pd.DataFrame(k_geo)
k_geo_df = k_geo_df.sort_values(by="accuracy", ascending=False)
# Out:
# k: 2
# 0.504103748053
#
# k: 3
# 0.510300794238
#
# k: 4
# 0.512300197731
#
# k: 5
# 0.515249594044
#
# k: 6
# 0.515580986888
#
# k: 7
# 0.516564118992
#
# k: 8
# 0.516807140411
#
# k: 9
# 0.520220486706
#
# k: 11
# 0.520629204547
#
# k: 15
# 0.522264075911
#
# k: 19
# 0.524970450805
#
# k: 23
# 0.525854165056
#
# k: 27
# 0.525257657936
#
# k: 31
# 0.525787886487
#
# k: 35
# 0.527146597148
#
# k: 39
# 0.527069272151
#
# k: 43
# 0.528240193533
#
# k: 47
# 0.528306472102
#
# k: 51
# 0.527234968573
#
# k: 71
# 0.533387829045
#
# k: 91
# 0.531841329106
#
# k: 111
# 0.534625028997
#
# k: 131
# 0.534359914722
#
# k: 151
# 0.536083157511
#
# k: 171
# 0.535398278966
#
# k: 191
# 0.535862228948
#
# k: 211
# 0.536425596783
#
# k: 231
# 0.536635478918
#
# k: 251
# 0.538524418129
#
# k: 271
# 0.539938360931
#
# k: 291
# 0.540943585892
#
# k: 311
# 0.541705789433
#
# k: 331
# 0.541716835861
#
# k: 351
# 0.542147646558
#
# k: 371
# 0.542324389409
#
# k: 391
# 0.542666828681
#
# k: 411
# 0.5432633358
#
# k: 431
# 0.544246467905
#
# k: 451
# 0.543926121489
#
# k: 471
# 0.543970307201
#
# k: 491
# 0.544301700045

# %%
freq_correct_signal = (train_signal["error_signal"] == train_signal["n_error_signal"]).value_counts()
print(freq_correct_signal[True] / len(train_signal))
freq_correct_signal
# Out:
# 0.544301700045
# True     49274
# False    41253
# dtype: int64

# %%
train_signal["error_signal"].value_counts()
# Out:
# 1.000     49870
# -1.000    39806
# 0.000       851
# Name: error_signal, dtype: int64

# %% [markdown]
# PLOTAR GRAFICO DE X = LOGERROR e Y = MÉDIA ERROS DE SINAL

# %%
error_0 = train[train["logerror"] == 0]
print(len(error_0))
# Out:
# 848

# %%
train_signal[train_signal["error_signal"] != train_signal["n_error_signal"]].head()
# Out:
# Empty DataFrame
# Columns: [latitude, longitude, logerror, error_signal, n_error_signal]
# Index: []

# %%
print(len(train["logerror"]), len(train.dropna(subset=["error_signal"])))
print(len(train_signal["logerror"]))
print(len(err_signal))

#(train["logerror"] == train_signal["logerror"]).value_counts()
# Out:
# 90811 89963
# 90219
# 89963

# %%
del train_signal["n_error_signal"]
